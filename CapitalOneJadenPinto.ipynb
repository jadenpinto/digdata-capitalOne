# %%
#Submitted by: Jaden Clive Pinto (jcp11@aber.ac.uk)

# %%
import pandas as pd

# %%
data = pd.read_csv('CapitalOneDataSet.csv')

# %%
data #entire dataset
# Out:
#       CUSTOMER_ID            REGION   AGE  PARENT     OCCUPATION  \
# 0               0           England  48.0       0       Employed
# 1               1  Northern Ireland  42.0       0       Employed
# 2               2           England  28.0       1       Employed
# 3               3           England  31.0       0     Unemployed
# 4               4           England  47.0       1        Student
# ...           ...               ...   ...     ...            ...
# 9995         9995           England  61.0       1        Retired
# 9996         9996           England  81.0       0       Employed
# 9997         9997           England  18.0       0  Self-employed
# 9998         9998          Scotland  46.0       0        Student
# 9999         9999           England  47.0       1       Employed
#
#       MOBILE_APP_USER CARD_COLOUR  CREDIT_LIMIT  SPEND_M1_TRAVEL  \
# 0                 1.0        Blue           250             5.71
# ...

# %%
data.shape #returns (rows,columns)
# Out:
# (10000, 15)

# %%
data.info() #returns information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CUSTOMER_ID       10000 non-null  int64
#  1   REGION            9965 non-null   object
#  2   AGE               9960 non-null   float64
#  3   PARENT            10000 non-null  int64
#  4   OCCUPATION        9958 non-null   object
#  5   MOBILE_APP_USER   9958 non-null   float64
#  6   CARD_COLOUR       9960 non-null   object
#  7   CREDIT_LIMIT      10000 non-null  int64
#  8   SPEND_M1_TRAVEL   10000 non-null  float64
#  9   SPEND_M1_GROCERY  10000 non-null  float64
#  10  SPEND_M1_OTHER    10000 non-null  float64
#  11  SPEND_M2_TRAVEL   10000 non-null  float64
#  12  SPEND_M2_GROCERY  10000 non-null  float64
#  13  SPEND_M2_OTHER    10000 non-null  float64
#  14  SPEND_M3_TOTAL    10000 non-null  float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        CUSTOMER_ID          AGE      PARENT  MOBILE_APP_USER  CREDIT_LIMIT  \
# count  10000.00000  9960.000000  10000.0000      9958.000000  10000.000000
# mean    4999.50000    45.919076      0.2909         0.710785    459.875000
# std     2886.89568    14.490208      0.4542         0.453421    274.529181
# min        0.00000    18.000000      0.0000         0.000000    250.000000
# 25%     2499.75000    35.000000      0.0000         0.000000    250.000000
# 50%     4999.50000    46.000000      0.0000         1.000000    250.000000
# 75%     7499.25000    56.000000      1.0000         1.000000    500.000000
# max     9999.00000    99.000000      1.0000         1.000000   1000.000000
#
#        SPEND_M1_TRAVEL  SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  \
# count     10000.000000      10000.000000    10000.000000     10000.000000
# mean         40.954998         45.079606       32.035493        40.633002
# ...

# %%
data.values
# Out:
# array([[0, 'England', 48.0, ..., 13.04, 7.49, 30.51],
#        [1, 'Northern Ireland', 42.0, ..., 0.0, 78.4, 20.41],
#        [2, 'England', 28.0, ..., 56.74, 18.74, 109.33],
#        ...,
#        [9997, 'England', 18.0, ..., 12.79, 4.35, 69.22],
#        [9998, 'Scotland', 46.0, ..., 16.02, 11.19, 52.89],
#        [9999, 'England', 47.0, ..., 59.58, 9.53, 107.3]], dtype=object)

# %%
data.values[0]
# Out:
# array([0, 'England', 48.0, 0, 'Employed', 1.0, 'Blue', 250, 5.71, 16.6,
#        4.95, 8.64, 13.04, 7.49, 30.51], dtype=object)

# %%
#input set = X
X = data.drop(columns=['CUSTOMER_ID','SPEND_M3_TOTAL'])

# %%
X
# Out:
#                 REGION   AGE  PARENT     OCCUPATION  MOBILE_APP_USER  \
# 0              England  48.0       0       Employed              1.0
# 1     Northern Ireland  42.0       0       Employed              1.0
# 2              England  28.0       1       Employed              1.0
# 3              England  31.0       0     Unemployed              1.0
# 4              England  47.0       1        Student              1.0
# ...                ...   ...     ...            ...              ...
# 9995           England  61.0       1        Retired              0.0
# 9996           England  81.0       0       Employed              1.0
# 9997           England  18.0       0  Self-employed              1.0
# 9998          Scotland  46.0       0        Student              0.0
# 9999           England  47.0       1       Employed              1.0
#
#      CARD_COLOUR  CREDIT_LIMIT  SPEND_M1_TRAVEL  SPEND_M1_GROCERY  \
# 0           Blue           250             5.71             16.60
# ...

# %%
#output set
y = data['SPEND_M3_TOTAL']

# %%
y
# Out:
# 0        30.51
# 1        20.41
# 2       109.33
# 3        50.34
# 4       184.99
#          ...
# 9995     39.06
# 9996    144.98
# 9997     69.22
# 9998     52.89
# 9999    107.30
# Name: SPEND_M3_TOTAL, Length: 10000, dtype: float64

# %%
#Learning and predicting - creating a model using a ML algorithm => Decision Tree
from sklearn.tree import DecisionTreeClassifier

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['CREDIT_LIMIT'],  data['SPEND_M3_TOTAL'])
plt.xlabel("CREDIT_LIMIT")
plt.ylabel("SPEND_M3_TOTAL")
plt.show()

# %%
plt.scatter(data['SPEND_M1_TRAVEL'],  data['SPEND_M3_TOTAL'])
plt.xlabel("SPEND_M1_TRAVEL")
plt.ylabel("SPEND_M3_TOTAL")
plt.show()

# %%
# if we trycreating the model:
# model = DecisionTreeClassifier()
# training it to learn patterns in the data - fit(input_set,output_set)
# model.fit(X,y)
# This will return: Value error - cannot use string - has to be a number

# %%
#input set = x (dropping all non number values)
x = data.drop(columns=['CUSTOMER_ID','SPEND_M3_TOTAL','REGION','OCCUPATION','CARD_COLOUR'])

# %%
x
# Out:
#        AGE  PARENT  MOBILE_APP_USER  CREDIT_LIMIT  SPEND_M1_TRAVEL  \
# 0     48.0       0              1.0           250             5.71
# 1     42.0       0              1.0           500            38.27
# 2     28.0       1              1.0           250            32.90
# 3     31.0       0              1.0           500            32.60
# 4     47.0       1              1.0          1000           262.42
# ...    ...     ...              ...           ...              ...
# 9995  61.0       1              0.0          1000            81.31
# 9996  81.0       0              1.0           250            56.32
# 9997  18.0       0              1.0           250            11.01
# 9998  46.0       0              0.0           500             8.52
# 9999  47.0       1              1.0           250            29.72
#
#       SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  SPEND_M2_GROCERY  \
# 0                16.60            4.95             8.64             13.04
# ...

# %%
x.describe()
# Out:
#                AGE      PARENT  MOBILE_APP_USER  CREDIT_LIMIT  \
# count  9960.000000  10000.0000      9958.000000  10000.000000
# mean     45.919076      0.2909         0.710785    459.875000
# std      14.490208      0.4542         0.453421    274.529181
# min      18.000000      0.0000         0.000000    250.000000
# 25%      35.000000      0.0000         0.000000    250.000000
# 50%      46.000000      0.0000         1.000000    250.000000
# 75%      56.000000      1.0000         1.000000    500.000000
# max      99.000000      1.0000         1.000000   1000.000000
#
#        SPEND_M1_TRAVEL  SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  \
# count     10000.000000      10000.000000    10000.000000     10000.000000
# mean         40.954998         45.079606       32.035493        40.633002
# std          54.583038         53.651382       45.116389        50.304390
# min           0.000000          0.000000        0.000000         0.000000
# ...

# %%
#creating the model
model = DecisionTreeClassifier()
#training it to learn patterns in the data - fit(input_set,output_set)
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c8c5e943f220> in <module>
#       2 model = DecisionTreeClassifier()
#       3 #training it to learn patterns in the data - fit(input_set,output_set)
# ----> 4 model.fit(x,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
# ...

# %%
x.isnull()
# Out:
#         AGE  PARENT  MOBILE_APP_USER  CREDIT_LIMIT  SPEND_M1_TRAVEL  \
# 0     False   False            False         False            False
# 1     False   False            False         False            False
# 2     False   False            False         False            False
# 3     False   False            False         False            False
# 4     False   False            False         False            False
# ...     ...     ...              ...           ...              ...
# 9995  False   False            False         False            False
# 9996  False   False            False         False            False
# 9997  False   False            False         False            False
# 9998  False   False            False         False            False
# 9999  False   False            False         False            False
#
#       SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  SPEND_M2_GROCERY  \
# 0                False           False            False             False
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AGE               9960 non-null   float64
#  1   PARENT            10000 non-null  int64
#  2   MOBILE_APP_USER   9958 non-null   float64
#  3   CREDIT_LIMIT      10000 non-null  int64
#  4   SPEND_M1_TRAVEL   10000 non-null  float64
#  5   SPEND_M1_GROCERY  10000 non-null  float64
#  6   SPEND_M1_OTHER    10000 non-null  float64
#  7   SPEND_M2_TRAVEL   10000 non-null  float64
#  8   SPEND_M2_GROCERY  10000 non-null  float64
#  9   SPEND_M2_OTHER    10000 non-null  float64
# dtypes: float64(8), int64(2)
# memory usage: 781.4 KB

# %%
x.dtypes
# Out:
# AGE                 float64
# PARENT                int64
# MOBILE_APP_USER     float64
# CREDIT_LIMIT          int64
# SPEND_M1_TRAVEL     float64
# SPEND_M1_GROCERY    float64
# SPEND_M1_OTHER      float64
# SPEND_M2_TRAVEL     float64
# SPEND_M2_GROCERY    float64
# SPEND_M2_OTHER      float64
# dtype: object

# %%
x['PARENT'] = x.PARENT.astype(float)

# %%
x['CREDIT_LIMIT'] = x.CREDIT_LIMIT.astype(float)

# %%
x.dtypes
# Out:
# AGE                 float64
# PARENT              float64
# MOBILE_APP_USER     float64
# CREDIT_LIMIT        float64
# SPEND_M1_TRAVEL     float64
# SPEND_M1_GROCERY    float64
# SPEND_M1_OTHER      float64
# SPEND_M2_TRAVEL     float64
# SPEND_M2_GROCERY    float64
# SPEND_M2_OTHER      float64
# dtype: object

# %%
#creating the model
model = DecisionTreeClassifier()
#training it to learn patterns in the data - fit(input_set,output_set)
model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-c8c5e943f220> in <module>
#       2 model = DecisionTreeClassifier()
#       3 #training it to learn patterns in the data - fit(input_set,output_set)
# ----> 4 model.fit(x,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     147
#     148         if check_input:
# --> 149             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     150             y = check_array(y, ensure_2d=False, dtype=None)
# ...

# %%
import numpy as np

# %%
np.isnan(x)
# Out:
#         AGE  PARENT  MOBILE_APP_USER  CREDIT_LIMIT  SPEND_M1_TRAVEL  \
# 0     False   False            False         False            False
# 1     False   False            False         False            False
# 2     False   False            False         False            False
# 3     False   False            False         False            False
# 4     False   False            False         False            False
# ...     ...     ...              ...           ...              ...
# 9995  False   False            False         False            False
# 9996  False   False            False         False            False
# 9997  False   False            False         False            False
# 9998  False   False            False         False            False
# 9999  False   False            False         False            False
#
#       SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  SPEND_M2_GROCERY  \
# 0                False           False            False             False
# ...

# %%
np.where(np.isnan(x))
# Out:
# (array([ 163,  342,  519, 1098, 1180, 1413, 1442, 1597, 1842, 2192, 2264,
#         2413, 2481, 2521, 2858, 2903, 2925, 2928, 2960, 3142, 3391, 3520,
#         3698, 3721, 3958, 3963, 4024, 4181, 4342, 4372, 4499, 4559, 4787,
#         4981, 5030, 5120, 5134, 5166, 5234, 5475, 5719, 5895, 6114, 6144,
#         6175, 6345, 6460, 6507, 6586, 6668, 6718, 6720, 6766, 6884, 7138,
#         7259, 7395, 7432, 7455, 7462, 7466, 7526, 7721, 7923, 8137, 8280,
#         8360, 8496, 8622, 8668, 8736, 8787, 9238, 9262, 9438, 9451, 9470,
#         9692, 9825, 9911, 9914, 9966], dtype=int64),
#  array([2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 0,
#         0, 0, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 2, 0, 0, 2, 2, 0, 0, 0,
#         0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 0, 2, 2,
#         2, 0, 2, 0, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0], dtype=int64))

# %%
len([ 163,342,  519, 1098, 1180, 1413, 1442, 1597, 1842, 2192, 2264,
        2413, 2481, 2521, 2858, 2903, 2925, 2928, 2960, 3142, 3391, 3520,
        3698, 3721, 3958, 3963, 4024, 4181, 4342, 4372, 4499, 4559, 4787,
        4981, 5030, 5120, 5134, 5166, 5234, 5475, 5719, 5895, 6114, 6144,
        6175, 6345, 6460, 6507, 6586, 6668, 6718, 6720, 6766, 6884, 7138,
        7259, 7395, 7432, 7455, 7462, 7466, 7526, 7721, 7923, 8137, 8280,
        8360, 8496, 8622, 8668, 8736, 8787, 9238, 9262, 9438, 9451, 9470,
        9692, 9825, 9911, 9914, 9966])
# Out:
# 82

# %%
len([2, 2, 2, 0, 0, 0, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 2, 0, 2, 0, 2, 0,
        0, 0, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 2, 0, 0, 2, 2, 0, 0, 0,
        0, 0, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 2, 2, 0, 2, 0, 2, 2,
        2, 0, 2, 0, 2, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 0])
# Out:
# 82

# %%
xx = np.array(x)

# %%
xx[163,2]
# Out:
# nan

# %%
# null/nan(not a number) = no entry

# %%
np.unique(np.where(np.isnan(x))[1])
# Out:
# array([0, 2], dtype=int64)

# %%
x #so nan values in AGE and MObILE APP USER
# Out:
#        AGE  PARENT  MOBILE_APP_USER  CREDIT_LIMIT  SPEND_M1_TRAVEL  \
# 0     48.0     0.0              1.0         250.0             5.71
# 1     42.0     0.0              1.0         500.0            38.27
# 2     28.0     1.0              1.0         250.0            32.90
# 3     31.0     0.0              1.0         500.0            32.60
# 4     47.0     1.0              1.0        1000.0           262.42
# ...    ...     ...              ...           ...              ...
# 9995  61.0     1.0              0.0        1000.0            81.31
# 9996  81.0     0.0              1.0         250.0            56.32
# 9997  18.0     0.0              1.0         250.0            11.01
# 9998  46.0     0.0              0.0         500.0             8.52
# 9999  47.0     1.0              1.0         250.0            29.72
#
#       SPEND_M1_GROCERY  SPEND_M1_OTHER  SPEND_M2_TRAVEL  SPEND_M2_GROCERY  \
# 0                16.60            4.95             8.64             13.04
# ...

# %%
xyz = np.nan_to_num(x) #replace nan with zero and inf with finite numbers

# %%
#creating the model
model = DecisionTreeClassifier()
#training it to learn patterns in the data - fit(input_set,output_set)
model.fit(xyz,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-cd751a748aca> in <module>
#       2 model = DecisionTreeClassifier()
#       3 #training it to learn patterns in the data - fit(input_set,output_set)
# ----> 4 model.fit(xyz,y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     171
#     172         if is_classification:
# --> 173             check_classification_targets(y)
#     174             y = np.copy(y)
#     175
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %%
clf = LogisticRegression()
clf.fit(xyz, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-fe292a5f84b3> in <module>
#       1 clf = LogisticRegression()
# ----> 2 clf.fit(xyz, y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1526         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1527                          accept_large_sparse=solver != 'liblinear')
# -> 1528         check_classification_targets(y)
#    1529         self.classes_ = np.unique(y)
#    1530         n_samples, n_features = X.shape
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# ...

# %%
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

# %%
clf = LogisticRegression()
clf.fit(xyz, training_scores_encoded)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
xyz
# Out:
# array([[48.  ,  0.  ,  1.  , ...,  8.64, 13.04,  7.49],
#        [42.  ,  0.  ,  1.  , ..., 90.1 ,  0.  , 78.4 ],
#        [28.  ,  1.  ,  1.  , ..., 36.07, 56.74, 18.74],
#        ...,
#        [18.  ,  0.  ,  1.  , ...,  7.98, 12.79,  4.35],
#        [46.  ,  0.  ,  0.  , ..., 16.58, 16.02, 11.19],
#        [47.  ,  1.  ,  1.  , ..., 59.69, 59.58,  9.53]])

# %%
#prediction_data_test = np.array([ [48, 0, 1, 250, 5.71, 16.6, 4,95, 8.64, 13.04, 7.49, 30.51] ])
prediction_data_test = np.array([[48, 0, 1, 250, 5.71, 16.6, 4.95, 8.64, 13.04,7.49]])

# %%
print(clf.predict(prediction_data_test))
# Out:
# [1001]

# %%
#creating the model
model = DecisionTreeClassifier()
#training it to learn patterns in the data - fit(input_set,output_set)
model.fit(xyz,training_scores_encoded)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
print(model.predict(prediction_data_test))
# Out:
# [1264]
